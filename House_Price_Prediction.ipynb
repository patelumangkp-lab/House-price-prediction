# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('House_Price.csv')
df
# Out:
#    Area    Price
# 0  3900  4500000
# 1  3800  4282000
# 2  3500  3900000
# 3  3600  4000000
# 4  3300  3500000
# 5  3200  3400000

# %%
plt.scatter(df['Area'], df['Price'], color = 'red', marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']],df['Price'])
# Out:
# LinearRegression()

# %%
print('Coefficient:', reg.coef_)
print('Intercept:', reg.intercept_)
# Out:
# Coefficient: [1561.33333333]
# Intercept: -1612400.0000000014

# %%
reg.predict([[3300]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3540000.])

# %%
reg.predict([[5000]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6194266.66666667])

# %%
1561.33333333*5000+(-1612400.0000000014)
# Out:
# 6194266.666649999

# %%
plt.scatter(df['Area'], df['Price'], color = 'red', marker='+')
plt.plot(df['Area'], reg.predict(df[['Area']]), color='blue')
plt.title('Area vs Price')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
df2 = pd.read_csv('Area.csv')
df2
# Out:
#    Area
# 0  1500
# 1  5000
# 2  3500
# 3  6222
# 4  8622
# 5  2300
# 6  4500
# 7  6300
# 8  8000

# %%
p = reg.predict(df2[['Area']])

# %%
df2['Price'] = p

# %%
df2.to_csv('Area_Price.csv', index=False)
df2
# Out:
#    Area         Price
# 0  1500  7.296000e+05
# 1  5000  6.194267e+06
# 2  3500  3.852267e+06
# 3  6222  8.102216e+06
# 4  8622  1.184942e+07
# 5  2300  1.978667e+06
# 6  4500  5.413600e+06
# 7  6300  8.224000e+06
# 8  8000  1.087827e+07
